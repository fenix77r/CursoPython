# %% [markdown]
# <a href="https://colab.research.google.com/github/fenix77r/CursoPython/blob/main/Clase_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
**Librerias**

CURSO PYTHON

UNICAFAM

ESTUDIANTE: MIGUEL FERNANDO RUIZ TINOCO

DOCENTE: NICOLAS MOJICA

# %%
#instalacion de Librerias

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Recargar un dataframe dentro de una variable a traves de la libreria pandas
marketing_data=pd.read_csv('/content/sample_data/correlacion_marketing_exp.csv')

# %%
marketing_data
# Out:
#     Campaña ID  Inversión en marketing (USD)  Ventas generadas (USD)  \
# 0            1                          5000                   25000
# 1            2                         10000                   60000
# 2            3                          7500                   40000
# 3            6                          6000                   30000
# 4            1                          5000                   25000
# ..         ...                           ...                     ...
# 95           5                          8000                   45000
# 96           3                          7500                   40000
# 97           1                          5000                   25000
# 98           6                          6000                   30000
# 99           3                          7500                   40000
#
#    Fecha de la campaña
# 0           2024-01-15
# 1           2024-02-20
# 2           2024-03-10
# 3           2024-06-15
# ...

# %%
marketing_data['Inversión en marketing (USD)']
# Out:
# 0      5000
# 1     10000
# 2      7500
# 3      6000
# 4      5000
#       ...
# 95     8000
# 96     7500
# 97     5000
# 98     6000
# 99     7500
# Name: Inversión en marketing (USD), Length: 100, dtype: int64

# %%
marketing_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Campaña ID                    100 non-null    int64
#  1   Inversión en marketing (USD)  100 non-null    int64
#  2   Ventas generadas (USD)        100 non-null    int64
#  3   Fecha de la campaña           100 non-null    object
#  4   utilidad                      100 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 4.0+ KB

# %%
# Medidas de tendencia central

marketing_data.describe()
# Out:
#        Campaña ID  Inversión en marketing (USD)  Ventas generadas (USD)
# count  100.000000                    100.000000              100.000000
# mean     3.500000                   6450.000000            36000.000000
# std      1.732051                   2520.121049            14616.304719
# min      1.000000                   2000.000000            15000.000000
# 25%      2.000000                   5000.000000            25000.000000
# 50%      3.500000                   6750.000000            35000.000000
# 75%      5.000000                   8000.000000            45000.000000
# max      6.000000                  10000.000000            60000.000000

# %%
#Operaciones de Reduccion
total_inversion_marketing=marketing_data['Inversión en marketing (USD)'].sum()
print(total_inversion_marketing)
# Out:
# 645000

# %%
# Insercion de una nueva columna en dataset

marketing_data["utilidad"]=marketing_data['Ventas generadas (USD)']-marketing_data['Inversión en marketing (USD)']
marketing_data
# Out:
#     Campaña ID  Inversión en marketing (USD)  Ventas generadas (USD)  \
# 0            1                          5000                   25000
# 1            2                         10000                   60000
# 2            3                          7500                   40000
# 3            6                          6000                   30000
# 4            1                          5000                   25000
# ..         ...                           ...                     ...
# 95           5                          8000                   45000
# 96           3                          7500                   40000
# 97           1                          5000                   25000
# 98           6                          6000                   30000
# 99           3                          7500                   40000
#
#    Fecha de la campaña  utilidad
# 0           2024-01-15     20000
# 1           2024-02-20     50000
# 2           2024-03-10     32500
# ...

# %%
# Union de datasets

data_ejecutivo=pd.read_excel('/content/sample_data/Taller2_ETL.xlsx')
data_ejecutivo
# Out:
#          CEDULA  N° Cuentas  N° CDT  N° Tarjetas De Crédito  \
# 0       9375240          64       2                      12
# 1    1023008416          93       6                      16
# 2      41960913          61       3                      10
# 3    1010229345          63       2                      14
# 4    1054920307          80       3                      15
# ..          ...         ...     ...                     ...
# 490  1019088583          50       3                       2
# 491    80807040          85       9                      12
# 492    80058124          74       1                       8
# 493    52067261          78       6                      12
# 494  1088008856          99       6                      19
#
#      N° Debitos Automáticos  Plan Familia (Millones)  Consumo (Millones)  \
# 0                         1             6.150000e+06        8.500000e+07
# 1                        10             9.930000e+06        9.197159e+07
# ...
